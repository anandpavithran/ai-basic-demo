# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
num_samples = 100
X_train = np.random.rand(num_samples, 2)
y_train = X_train[:, 0] + X_train[:, 1]
model = Sequential()
model.add(Dense(8, input_shape=(2,), activation='relu'))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
batch_size = 10
epochs = 5
model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1)
test_input = np.array([[1, 2], [0.3, 0.4]])
predicted_sum = model.predict(test_input)
print("Predicted sums:")
print(predicted_sum)
# Out:
# 2025-09-17 09:31:36.687037: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-17 09:31:36.689283: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-17 09:31:36.854694: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-17 09:31:37.998239: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-17 09:31:37.998553: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Epoch 1/5
# /home/anandpavithran/.local/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-09-17 09:31:38.919111: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4570
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3332
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2038
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0739
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9502
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted sums:
# [[0.03924001]
#  [0.12329264]]
