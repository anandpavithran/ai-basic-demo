# %%
# !pip install ydata_profiling
# !pip install sweetviz
import pandas as pd
from ydata_profiling import ProfileReport
import sweetviz as sv

# Load dataset
df = pd.read_csv("data.csv")

# Quick automated report
profile = ProfileReport(df, title="EDA Report")
profile.to_file("report.html")

# Sweetviz comparison example
report = sv.analyze([df, "Dataset"])
report.show_html("sweetviz_report.html")

# Continue with manual refinement if needed
print(df.isnull().sum())
print(df.describe())
# Out:
# Requirement already satisfied: ydata_profiling in /opt/app-root/lib/python3.9/site-packages (4.17.0)
# Requirement already satisfied: imagehash==4.3.1 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (4.3.1)
# Requirement already satisfied: dacite>=1.8 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (1.9.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (3.1.4)
# Requirement already satisfied: multimethod<2,>=1.4 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (1.12)
# Requirement already satisfied: minify-html>=0.15.0 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (0.18.1)
# Requirement already satisfied: typeguard<5,>=3 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (4.4.4)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (0.14.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (0.13.2)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (2.2.2)
# Requirement already satisfied: visions[type_image_path]<0.8.2,>=0.7.5 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (0.8.1)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (1.12.0)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (1.26.4)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (0.12.5)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (0.60.0)
# Requirement already satisfied: pydantic>=2 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (2.12.3)
# Requirement already satisfied: requests<3,>=2.24.0 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (2.32.3)
# Requirement already satisfied: filetype>=1.0.0 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (1.2.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (4.66.5)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (3.8.4)
# Requirement already satisfied: wordcloud>=1.9.3 in /opt/app-root/lib/python3.9/site-packages (from ydata_profiling) (1.9.4)
# Requirement already satisfied: pillow in /opt/app-root/lib/python3.9/site-packages (from imagehash==4.3.1->ydata_profiling) (10.4.0)
# Requirement already satisfied: PyWavelets in /opt/app-root/lib/python3.9/site-packages (from imagehash==4.3.1->ydata_profiling) (1.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (2.1.5)
# Requirement already satisfied: cycler>=0.10 in /opt/app-root/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/app-root/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (4.53.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/app-root/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (6.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (3.1.4)
# Requirement already satisfied: packaging>=20.0 in /opt/app-root/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (24.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/app-root/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.4.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/app-root/lib/python3.9/site-packages (from numba<=0.61,>=0.56.0->ydata_profiling) (0.43.0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/app-root/lib/python3.9/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata_profiling) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.9/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata_profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /opt/app-root/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/app-root/lib/python3.9/site-packages (from pydantic>=2->ydata_profiling) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/app-root/lib/python3.9/site-packages (from pydantic>=2->ydata_profiling) (4.15.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/app-root/lib/python3.9/site-packages (from pydantic>=2->ydata_profiling) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/app-root/lib/python3.9/site-packages (from pydantic>=2->ydata_profiling) (0.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata_profiling) (1.26.19)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata_profiling) (2024.7.4)
# Requirement already satisfied: patsy>=0.5.6 in /opt/app-root/lib/python3.9/site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (1.0.2)
# Requirement already satisfied: importlib_metadata>=3.6 in /opt/app-root/lib/python3.9/site-packages (from typeguard<5,>=3->ydata_profiling) (8.4.0)
# WARNING: visions 0.8.1 does not provide the extra 'type_image_path'
# Requirement already satisfied: attrs>=19.3.0 in /opt/app-root/lib/python3.9/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (24.2.0)
# Requirement already satisfied: puremagic in /opt/app-root/lib/python3.9/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (1.30)
# Requirement already satisfied: networkx>=2.4 in /opt/app-root/lib/python3.9/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (3.2.1)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.9/site-packages (from importlib_metadata>=3.6->typeguard<5,>=3->ydata_profiling) (3.20.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata_profiling) (1.16.0)
#
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sweetviz in /opt/app-root/lib/python3.9/site-packages (2.3.1)
# Requirement already satisfied: importlib-resources>=1.2.0 in /opt/app-root/lib/python3.9/site-packages (from sweetviz) (6.4.4)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /opt/app-root/lib/python3.9/site-packages (from sweetviz) (2.2.2)
# Requirement already satisfied: tqdm>=4.43.0 in /opt/app-root/lib/python3.9/site-packages (from sweetviz) (4.66.5)
# Requirement already satisfied: numpy>=1.16.0 in /opt/app-root/lib/python3.9/site-packages (from sweetviz) (1.26.4)
# Requirement already satisfied: jinja2>=2.11.1 in /opt/app-root/lib/python3.9/site-packages (from sweetviz) (3.1.4)
# Requirement already satisfied: scipy>=1.3.2 in /opt/app-root/lib/python3.9/site-packages (from sweetviz) (1.12.0)
# Requirement already satisfied: matplotlib>=3.1.3 in /opt/app-root/lib/python3.9/site-packages (from sweetviz) (3.8.4)
# Requirement already satisfied: zipp>=3.1.0 in /opt/app-root/lib/python3.9/site-packages (from importlib-resources>=1.2.0->sweetviz) (3.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.9/site-packages (from jinja2>=2.11.1->sweetviz) (2.1.5)
# Requirement already satisfied: pillow>=8 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (4.53.1)
# Requirement already satisfied: packaging>=20.0 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (24.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/app-root/lib/python3.9/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.9/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
#
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# /opt/app-root/lib64/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/14 [00:00<?, ?it/s]
# 100%|██████████| 14/14 [00:00<00:00, 32.81it/s][A
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
#                                              |          | [  0%]   00:00 -> (? left)
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# yr      0
# mo      0
# dy      0
# date    0
# st      0
# mag     0
# inj     0
# fat     0
# slat    0
# slon    0
# elat    0
# elon    0
# len     0
# wid     0
# dtype: int64
#                  yr            mo            dy           mag           inj  \
# count  67558.000000  67558.000000  67558.000000  67558.000000  67558.000000
# mean    1991.341618      5.976761     15.921016      0.691273      1.437876
# std       19.330015      2.438192      8.736773      1.283375     18.263956
# min     1950.000000      1.000000      1.000000     -9.000000      0.000000
# 25%     1976.000000      4.000000      8.000000      0.000000      0.000000
# 50%     1994.000000      6.000000     16.000000      1.000000      0.000000
# 75%     2008.000000      7.000000     24.000000      1.000000      0.000000
# max     2021.000000     12.000000     31.000000      5.000000   1740.000000
#
#                 fat          slat          slon          elat          elon  \
# count  67558.000000  67558.000000  67558.000000  67558.000000  67558.000000
# mean       0.090470     37.142412    -92.784618     22.730695    -56.245590
# std        1.484106      5.093979      8.689103     18.588638     45.489157
# min        0.000000     17.721200   -163.530000      0.000000   -163.530000
# 25%        0.000000     33.220000    -98.450000      0.000000    -94.709800
# 50%        0.000000     37.030000    -93.600000     32.480000    -84.420000
# 75%        0.000000     40.930000    -86.730000     38.610000      0.000000
# max      158.000000     61.020000    -64.715100     61.020000      0.000000
#
#                 len           wid
# count  67558.000000  67558.000000
# mean       3.478340    106.577030
# std        8.278775    205.802676
# min        0.000000      0.000000
# 25%        0.100000     20.000000
# 50%        0.800000     50.000000
# 75%        3.130000    100.000000
# max      234.700000   4576.000000
